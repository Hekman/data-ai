# %% [markdown]
# # Block A · Week 7 — Interactive Interface
#
# **This week's question:** *How do I turn my data story into an interactive interface for a real audience?*
#
# Work through this notebook in your hosted environment. Read the week `README.md` first.

# %%
import pandas as pd

# datasets for this week live in ./data/
