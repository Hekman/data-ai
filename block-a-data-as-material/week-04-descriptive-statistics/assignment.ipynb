# %% [markdown]
# # Block A · Week 4 — Descriptive Statistics
#
# **This week's question:** *How do I summarise a dataset honestly — and see what a summary hides?*
#
# Work through this notebook in your hosted environment. Read the week `README.md` first.

# %%
import pandas as pd

# datasets for this week live in ./data/
