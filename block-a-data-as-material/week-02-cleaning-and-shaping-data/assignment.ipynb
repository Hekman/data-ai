# %% [markdown]
# # Block A · Week 2 — Cleaning & Shaping Data
#
# **This week's question:** *How do I turn messy, real-world data into a table I can trust?*
#
# Work through this notebook in your hosted environment. Read the week `README.md` first.

# %%
import pandas as pd

# datasets for this week live in ./data/
