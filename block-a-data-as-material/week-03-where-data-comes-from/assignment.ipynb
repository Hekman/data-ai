# %% [markdown]
# # Block A · Week 3 — Where Data Comes From
#
# **This week's question:** *Where does this data come from, who made it, and what is missing?*
#
# Work through this notebook in your hosted environment. Read the week `README.md` first.

# %%
import pandas as pd

# datasets for this week live in ./data/
