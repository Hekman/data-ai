# %% [markdown]
# # Block A · Week 6 — Data Visualisation & Dashboards
#
# **This week's question:** *How do I show data so an audience can read it — and build a simple dashboard?*
#
# Work through this notebook in your hosted environment. Read the week `README.md` first.

# %%
import pandas as pd

# datasets for this week live in ./data/
